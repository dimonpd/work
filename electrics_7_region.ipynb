# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Считываем  данные за 23 год по ср то на клиента

# %%
df_electric_7_region_23 = pd.read_excel('C:/Users/dimon/Downloads/electric_7_region_23.xlsx', index_col=0, skiprows=2)

# %%
df_electric_7_region_23
# Out:
#             region_name            Магазин  \
# Направление
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# ...                 ...                ...
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
#
#                                                         Клиент  dep  subdep  \
# Направление
# Электрика          Филиал ООО «ТС СТАНДАРТПАРК» г. Новосибирск    3     310
# Электрика                                 АНО ОШ "ПРОСВЕЩЕНИЕ"    3     310
# Электрика                                 АНО СПО "НГОК", НГОК    3     305
# Электрика                                 АНО СПО "НГОК", НГОК    3     310
# ...

# %% [markdown]
# Считываем  данные за 24 год по ср то на клиента

# %%
df_electric_7_region_24 = pd.read_excel('C:/Users/dimon/Downloads/electric_7_region_24.xlsx', index_col=0, skiprows=2)

# %%
df_electric_7_region_24
# Out:
#             region_name            Магазин  \
# Направление
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# Электрика      Регион 7    012 НОВОСИБИРСК
# ...                 ...                ...
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
# Электрика      Регион 7  129 Новокузнецк 2
#
#                                                         Клиент  dep  subdep  \
# Направление
# Электрика                        АО "АТП №3 "НОВОСИБИРСКСТРОЙ"    3     310
# Электрика                        АО "АТП №3 "НОВОСИБИРСКСТРОЙ"    3     310
# Электрика                            АО "ГЛАВНОВОСИБИРСКСТРОЙ"    3     310
# Электрика                            АО "ГЛАВНОВОСИБИРСКСТРОЙ"    3     310
# ...

# %% [markdown]
# Нужно сравнить данные за 23 и 24 годы по ср то на клиента в рамках каждого магазина отдельно. Для этого сгруппируем данные по магазинам.

# %%
df_group23 = df_electric_7_region_23.groupby('Магазин').

# %%
df_group23
