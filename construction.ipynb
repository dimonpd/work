# %%
import pandas as pd
import numpy as np

# %%
#Create a public URL
#https://docs.google.com/spreadsheets/d/1S9kV13rNGrMQAKpOhRJW9tI0LimT6Jw6T2HPdIz00W0/edit?gid=0#gid=0 construction
#https://docs.google.com/spreadsheets/d/1S9kV13rNGrMQAKpOhRJW9tI0LimT6Jw6T2HPdIz00W0/edit?gid=1413065181#gid=1413065181 developer

#get spreadsheets key from url
gsheetke_construction = "1S9kV13rNGrMQAKpOhRJW9tI0LimT6Jw6T2HPdIz00W0"

#sheet name
sheet_name = 'construction'

url=f'https://docs.google.com/spreadsheet/ccc?key={gsheetkey}&output=xlsx'
df = pd.read_excel(url,sheet_name='1',index_col=0)

# %%
sheet_name = 's_construction' # replace with your own sheet name
sheet_id = '1S9kV13rNGrMQAKpOhRJW9tI0LimT6Jw6T2HPdIz00W0' # replace with your sheet's ID

# %%
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#                            Регион  Строящихся домов ед.      %  \
# 0                          Москва                 748.0  6,30%
# 1              Московская область                 715.0  6,10%
# 2              Краснодарский край                 853.0  7,20%
# 3                 Санкт-Петербург                 449.0  3,80%
# 4            Свердловская область                 403.0  3,40%
# ..                            ...                   ...    ...
# 80               Республика Алтай                  11.0  0,10%
# 81           Республика Ингушетия                   3.0  0,00%
# 82  Луганская Народная Республика                   3.0  0,00%
# 83             Мурманская область                   1.0  0,00%
# 84                     Общий итог                   NaN   100%
#
#    Жилых единиц ед.( квартиры, аппартаменты)     %.1  \
# 0                                    378 635  15,40%
# 1                                    205 834   8,40%
# ...
